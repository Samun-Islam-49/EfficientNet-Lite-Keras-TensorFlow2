# %%
from efficientnet_lite import EfficientNetLiteB0, EfficientNetLiteB1, EfficientNetLiteB2, EfficientNetLiteB3, EfficientNetLiteB4

# %%
# Load the models as the same way as other Keras Applications Models
# You can use weights = None|"imagenet"|path_to_your_weights_file to load pre-trained imageNet1K weights or custom weights. (Default: "imagenet")
# You can set include_top = True|False to include/exclude the final classification layer. (Default: True)
# You must pass either input_tensor or input_shape. (Default: None)
# You can pass model_name to set the model's name. (Default: "efficientnet_lite_b{0-4}")
# See the efficinetnet_lite.py file for more details.
cnn_model = EfficientNetLiteB0(input_shape = (224, 224, 3), weights = "imagenet", include_top = False)

# You can freeze or unfreeze the whole model or specific layers as usual for fine-tuning.
cnn_model.trainable = True

print(f"Name : {cnn_model.name}")
print(f"Total Layers : {len(cnn_model.layers)}")
# cnn_model.summary(show_trainable=True)
# Out:
# Name : efficientnet_lite_b0
# Total Layers : 155

# %%
# Example Model Building with Top Classification Layer
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model

imput_tensor = cnn_model.input
x = GlobalAveragePooling2D()(cnn_model.output)
x = Dense(128, activation='relu')(x)
output_tensor = Dense(10, activation='softmax')(x)

model = Model(inputs=imput_tensor, outputs=output_tensor, name="EfficientNetLiteB0_CustomTop")
model.summary(show_trainable=True)
# Out:
# Model: "EfficientNetLiteB0_CustomTop"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_8     │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ stem_conv_pad     │ (None, 225,     │         0 │ input_layer_8… │   -   │
# │ (ZeroPadding2D)   │ 225, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ stem_conv         │ (None, 112,     │       864 │ stem_conv_pad… │   Y   │
# │ (Conv2D)          │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ stem_bn           │ (None, 112,     │       128 │ stem_conv[0][… │   Y   │
# │ (BatchNormalizat… │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ stem_activation   │ (None, 112,     │         0 │ stem_bn[0][0]  │   -   │
# │ (Activation)      │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1a_dwconv    │ (None, 112,     │       288 │ stem_activati… │   Y   │
# │ (DepthwiseConv2D) │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1a_bn        │ (None, 112,     │       128 │ block1a_dwcon… │   Y   │
# │ (BatchNormalizat… │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1a_activati… │ (None, 112,     │         0 │ block1a_bn[0]… │   -   │
# │ (Activation)      │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1a_project_… │ (None, 112,     │       512 │ block1a_activ… │   Y   │
# │ (Conv2D)          │ 112, 16)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1a_project_… │ (None, 112,     │        64 │ block1a_proje… │   Y   │
# │ (BatchNormalizat… │ 112, 16)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_expand_c… │ (None, 112,     │     1,536 │ block1a_proje… │   Y   │
# │ (Conv2D)          │ 112, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_expand_bn │ (None, 112,     │       384 │ block2a_expan… │   Y   │
# │ (BatchNormalizat… │ 112, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_expand_a… │ (None, 112,     │         0 │ block2a_expan… │   -   │
# │ (Activation)      │ 112, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_dwconv_p… │ (None, 113,     │         0 │ block2a_expan… │   -   │
# │ (ZeroPadding2D)   │ 113, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_dwconv    │ (None, 56, 56,  │       864 │ block2a_dwcon… │   Y   │
# │ (DepthwiseConv2D) │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_bn        │ (None, 56, 56,  │       384 │ block2a_dwcon… │   Y   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_activati… │ (None, 56, 56,  │         0 │ block2a_bn[0]… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_project_… │ (None, 56, 56,  │     2,304 │ block2a_activ… │   Y   │
# │ (Conv2D)          │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2a_project_… │ (None, 56, 56,  │        96 │ block2a_proje… │   Y   │
# │ (BatchNormalizat… │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_expand_c… │ (None, 56, 56,  │     3,456 │ block2a_proje… │   Y   │
# │ (Conv2D)          │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_expand_bn │ (None, 56, 56,  │       576 │ block2b_expan… │   Y   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_expand_a… │ (None, 56, 56,  │         0 │ block2b_expan… │   -   │
# │ (Activation)      │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_dwconv    │ (None, 56, 56,  │     1,296 │ block2b_expan… │   Y   │
# │ (DepthwiseConv2D) │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_bn        │ (None, 56, 56,  │       576 │ block2b_dwcon… │   Y   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_activati… │ (None, 56, 56,  │         0 │ block2b_bn[0]… │   -   │
# │ (Activation)      │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_project_… │ (None, 56, 56,  │     3,456 │ block2b_activ… │   Y   │
# │ (Conv2D)          │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_project_… │ (None, 56, 56,  │        96 │ block2b_proje… │   Y   │
# │ (BatchNormalizat… │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_drop      │ (None, 56, 56,  │         0 │ block2b_proje… │   -   │
# │ (Dropout)         │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2b_add (Add) │ (None, 56, 56,  │         0 │ block2b_drop[… │   -   │
# │                   │ 24)             │           │ block2a_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_expand_c… │ (None, 56, 56,  │     3,456 │ block2b_add[0… │   Y   │
# │ (Conv2D)          │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_expand_bn │ (None, 56, 56,  │       576 │ block3a_expan… │   Y   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_expand_a… │ (None, 56, 56,  │         0 │ block3a_expan… │   -   │
# │ (Activation)      │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_dwconv_p… │ (None, 59, 59,  │         0 │ block3a_expan… │   -   │
# │ (ZeroPadding2D)   │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_dwconv    │ (None, 28, 28,  │     3,600 │ block3a_dwcon… │   Y   │
# │ (DepthwiseConv2D) │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_bn        │ (None, 28, 28,  │       576 │ block3a_dwcon… │   Y   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_activati… │ (None, 28, 28,  │         0 │ block3a_bn[0]… │   -   │
# │ (Activation)      │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_project_… │ (None, 28, 28,  │     5,760 │ block3a_activ… │   Y   │
# │ (Conv2D)          │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3a_project_… │ (None, 28, 28,  │       160 │ block3a_proje… │   Y   │
# │ (BatchNormalizat… │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_expand_c… │ (None, 28, 28,  │     9,600 │ block3a_proje… │   Y   │
# │ (Conv2D)          │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_expand_bn │ (None, 28, 28,  │       960 │ block3b_expan… │   Y   │
# │ (BatchNormalizat… │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_expand_a… │ (None, 28, 28,  │         0 │ block3b_expan… │   -   │
# │ (Activation)      │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_dwconv    │ (None, 28, 28,  │     6,000 │ block3b_expan… │   Y   │
# │ (DepthwiseConv2D) │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_bn        │ (None, 28, 28,  │       960 │ block3b_dwcon… │   Y   │
# │ (BatchNormalizat… │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_activati… │ (None, 28, 28,  │         0 │ block3b_bn[0]… │   -   │
# │ (Activation)      │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_project_… │ (None, 28, 28,  │     9,600 │ block3b_activ… │   Y   │
# │ (Conv2D)          │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_project_… │ (None, 28, 28,  │       160 │ block3b_proje… │   Y   │
# │ (BatchNormalizat… │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_drop      │ (None, 28, 28,  │         0 │ block3b_proje… │   -   │
# │ (Dropout)         │ 40)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3b_add (Add) │ (None, 28, 28,  │         0 │ block3b_drop[… │   -   │
# │                   │ 40)             │           │ block3a_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_expand_c… │ (None, 28, 28,  │     9,600 │ block3b_add[0… │   Y   │
# │ (Conv2D)          │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_expand_bn │ (None, 28, 28,  │       960 │ block4a_expan… │   Y   │
# │ (BatchNormalizat… │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_expand_a… │ (None, 28, 28,  │         0 │ block4a_expan… │   -   │
# │ (Activation)      │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_dwconv_p… │ (None, 29, 29,  │         0 │ block4a_expan… │   -   │
# │ (ZeroPadding2D)   │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_dwconv    │ (None, 14, 14,  │     2,160 │ block4a_dwcon… │   Y   │
# │ (DepthwiseConv2D) │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_bn        │ (None, 14, 14,  │       960 │ block4a_dwcon… │   Y   │
# │ (BatchNormalizat… │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_activati… │ (None, 14, 14,  │         0 │ block4a_bn[0]… │   -   │
# │ (Activation)      │ 240)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_project_… │ (None, 14, 14,  │    19,200 │ block4a_activ… │   Y   │
# │ (Conv2D)          │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4a_project_… │ (None, 14, 14,  │       320 │ block4a_proje… │   Y   │
# │ (BatchNormalizat… │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_expand_c… │ (None, 14, 14,  │    38,400 │ block4a_proje… │   Y   │
# │ (Conv2D)          │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_expand_bn │ (None, 14, 14,  │     1,920 │ block4b_expan… │   Y   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_expand_a… │ (None, 14, 14,  │         0 │ block4b_expan… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_dwconv    │ (None, 14, 14,  │     4,320 │ block4b_expan… │   Y   │
# │ (DepthwiseConv2D) │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_bn        │ (None, 14, 14,  │     1,920 │ block4b_dwcon… │   Y   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_activati… │ (None, 14, 14,  │         0 │ block4b_bn[0]… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_project_… │ (None, 14, 14,  │    38,400 │ block4b_activ… │   Y   │
# │ (Conv2D)          │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_project_… │ (None, 14, 14,  │       320 │ block4b_proje… │   Y   │
# │ (BatchNormalizat… │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_drop      │ (None, 14, 14,  │         0 │ block4b_proje… │   -   │
# │ (Dropout)         │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4b_add (Add) │ (None, 14, 14,  │         0 │ block4b_drop[… │   -   │
# │                   │ 80)             │           │ block4a_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_expand_c… │ (None, 14, 14,  │    38,400 │ block4b_add[0… │   Y   │
# │ (Conv2D)          │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_expand_bn │ (None, 14, 14,  │     1,920 │ block4c_expan… │   Y   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_expand_a… │ (None, 14, 14,  │         0 │ block4c_expan… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_dwconv    │ (None, 14, 14,  │     4,320 │ block4c_expan… │   Y   │
# │ (DepthwiseConv2D) │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_bn        │ (None, 14, 14,  │     1,920 │ block4c_dwcon… │   Y   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_activati… │ (None, 14, 14,  │         0 │ block4c_bn[0]… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_project_… │ (None, 14, 14,  │    38,400 │ block4c_activ… │   Y   │
# │ (Conv2D)          │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_project_… │ (None, 14, 14,  │       320 │ block4c_proje… │   Y   │
# │ (BatchNormalizat… │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_drop      │ (None, 14, 14,  │         0 │ block4c_proje… │   -   │
# │ (Dropout)         │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4c_add (Add) │ (None, 14, 14,  │         0 │ block4c_drop[… │   -   │
# │                   │ 80)             │           │ block4b_add[0… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_expand_c… │ (None, 14, 14,  │    38,400 │ block4c_add[0… │   Y   │
# │ (Conv2D)          │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_expand_bn │ (None, 14, 14,  │     1,920 │ block5a_expan… │   Y   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_expand_a… │ (None, 14, 14,  │         0 │ block5a_expan… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_dwconv    │ (None, 14, 14,  │    12,000 │ block5a_expan… │   Y   │
# │ (DepthwiseConv2D) │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_bn        │ (None, 14, 14,  │     1,920 │ block5a_dwcon… │   Y   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_activati… │ (None, 14, 14,  │         0 │ block5a_bn[0]… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_project_… │ (None, 14, 14,  │    53,760 │ block5a_activ… │   Y   │
# │ (Conv2D)          │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5a_project_… │ (None, 14, 14,  │       448 │ block5a_proje… │   Y   │
# │ (BatchNormalizat… │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_expand_c… │ (None, 14, 14,  │    75,264 │ block5a_proje… │   Y   │
# │ (Conv2D)          │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_expand_bn │ (None, 14, 14,  │     2,688 │ block5b_expan… │   Y   │
# │ (BatchNormalizat… │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_expand_a… │ (None, 14, 14,  │         0 │ block5b_expan… │   -   │
# │ (Activation)      │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_dwconv    │ (None, 14, 14,  │    16,800 │ block5b_expan… │   Y   │
# │ (DepthwiseConv2D) │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_bn        │ (None, 14, 14,  │     2,688 │ block5b_dwcon… │   Y   │
# │ (BatchNormalizat… │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_activati… │ (None, 14, 14,  │         0 │ block5b_bn[0]… │   -   │
# │ (Activation)      │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_project_… │ (None, 14, 14,  │    75,264 │ block5b_activ… │   Y   │
# │ (Conv2D)          │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_project_… │ (None, 14, 14,  │       448 │ block5b_proje… │   Y   │
# │ (BatchNormalizat… │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_drop      │ (None, 14, 14,  │         0 │ block5b_proje… │   -   │
# │ (Dropout)         │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5b_add (Add) │ (None, 14, 14,  │         0 │ block5b_drop[… │   -   │
# │                   │ 112)            │           │ block5a_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_expand_c… │ (None, 14, 14,  │    75,264 │ block5b_add[0… │   Y   │
# │ (Conv2D)          │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_expand_bn │ (None, 14, 14,  │     2,688 │ block5c_expan… │   Y   │
# │ (BatchNormalizat… │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_expand_a… │ (None, 14, 14,  │         0 │ block5c_expan… │   -   │
# │ (Activation)      │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_dwconv    │ (None, 14, 14,  │    16,800 │ block5c_expan… │   Y   │
# │ (DepthwiseConv2D) │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_bn        │ (None, 14, 14,  │     2,688 │ block5c_dwcon… │   Y   │
# │ (BatchNormalizat… │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_activati… │ (None, 14, 14,  │         0 │ block5c_bn[0]… │   -   │
# │ (Activation)      │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_project_… │ (None, 14, 14,  │    75,264 │ block5c_activ… │   Y   │
# │ (Conv2D)          │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_project_… │ (None, 14, 14,  │       448 │ block5c_proje… │   Y   │
# │ (BatchNormalizat… │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_drop      │ (None, 14, 14,  │         0 │ block5c_proje… │   -   │
# │ (Dropout)         │ 112)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5c_add (Add) │ (None, 14, 14,  │         0 │ block5c_drop[… │   -   │
# │                   │ 112)            │           │ block5b_add[0… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_expand_c… │ (None, 14, 14,  │    75,264 │ block5c_add[0… │   Y   │
# │ (Conv2D)          │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_expand_bn │ (None, 14, 14,  │     2,688 │ block6a_expan… │   Y   │
# │ (BatchNormalizat… │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_expand_a… │ (None, 14, 14,  │         0 │ block6a_expan… │   -   │
# │ (Activation)      │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_dwconv_p… │ (None, 17, 17,  │         0 │ block6a_expan… │   -   │
# │ (ZeroPadding2D)   │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_dwconv    │ (None, 7, 7,    │    16,800 │ block6a_dwcon… │   Y   │
# │ (DepthwiseConv2D) │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_bn        │ (None, 7, 7,    │     2,688 │ block6a_dwcon… │   Y   │
# │ (BatchNormalizat… │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_activati… │ (None, 7, 7,    │         0 │ block6a_bn[0]… │   -   │
# │ (Activation)      │ 672)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_project_… │ (None, 7, 7,    │   129,024 │ block6a_activ… │   Y   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6a_project_… │ (None, 7, 7,    │       768 │ block6a_proje… │   Y   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_expand_c… │ (None, 7, 7,    │   221,184 │ block6a_proje… │   Y   │
# │ (Conv2D)          │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_expand_bn │ (None, 7, 7,    │     4,608 │ block6b_expan… │   Y   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_expand_a… │ (None, 7, 7,    │         0 │ block6b_expan… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_dwconv    │ (None, 7, 7,    │    28,800 │ block6b_expan… │   Y   │
# │ (DepthwiseConv2D) │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_bn        │ (None, 7, 7,    │     4,608 │ block6b_dwcon… │   Y   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_activati… │ (None, 7, 7,    │         0 │ block6b_bn[0]… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_project_… │ (None, 7, 7,    │   221,184 │ block6b_activ… │   Y   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_project_… │ (None, 7, 7,    │       768 │ block6b_proje… │   Y   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_drop      │ (None, 7, 7,    │         0 │ block6b_proje… │   -   │
# │ (Dropout)         │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6b_add (Add) │ (None, 7, 7,    │         0 │ block6b_drop[… │   -   │
# │                   │ 192)            │           │ block6a_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_expand_c… │ (None, 7, 7,    │   221,184 │ block6b_add[0… │   Y   │
# │ (Conv2D)          │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_expand_bn │ (None, 7, 7,    │     4,608 │ block6c_expan… │   Y   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_expand_a… │ (None, 7, 7,    │         0 │ block6c_expan… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_dwconv    │ (None, 7, 7,    │    28,800 │ block6c_expan… │   Y   │
# │ (DepthwiseConv2D) │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_bn        │ (None, 7, 7,    │     4,608 │ block6c_dwcon… │   Y   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_activati… │ (None, 7, 7,    │         0 │ block6c_bn[0]… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_project_… │ (None, 7, 7,    │   221,184 │ block6c_activ… │   Y   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_project_… │ (None, 7, 7,    │       768 │ block6c_proje… │   Y   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_drop      │ (None, 7, 7,    │         0 │ block6c_proje… │   -   │
# │ (Dropout)         │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6c_add (Add) │ (None, 7, 7,    │         0 │ block6c_drop[… │   -   │
# │                   │ 192)            │           │ block6b_add[0… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_expand_c… │ (None, 7, 7,    │   221,184 │ block6c_add[0… │   Y   │
# │ (Conv2D)          │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_expand_bn │ (None, 7, 7,    │     4,608 │ block6d_expan… │   Y   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_expand_a… │ (None, 7, 7,    │         0 │ block6d_expan… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_dwconv    │ (None, 7, 7,    │    28,800 │ block6d_expan… │   Y   │
# │ (DepthwiseConv2D) │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_bn        │ (None, 7, 7,    │     4,608 │ block6d_dwcon… │   Y   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_activati… │ (None, 7, 7,    │         0 │ block6d_bn[0]… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_project_… │ (None, 7, 7,    │   221,184 │ block6d_activ… │   Y   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_project_… │ (None, 7, 7,    │       768 │ block6d_proje… │   Y   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_drop      │ (None, 7, 7,    │         0 │ block6d_proje… │   -   │
# │ (Dropout)         │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6d_add (Add) │ (None, 7, 7,    │         0 │ block6d_drop[… │   -   │
# │                   │ 192)            │           │ block6c_add[0… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_expand_c… │ (None, 7, 7,    │   221,184 │ block6d_add[0… │   Y   │
# │ (Conv2D)          │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_expand_bn │ (None, 7, 7,    │     4,608 │ block7a_expan… │   Y   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_expand_a… │ (None, 7, 7,    │         0 │ block7a_expan… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_dwconv    │ (None, 7, 7,    │    10,368 │ block7a_expan… │   Y   │
# │ (DepthwiseConv2D) │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_bn        │ (None, 7, 7,    │     4,608 │ block7a_dwcon… │   Y   │
# │ (BatchNormalizat… │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_activati… │ (None, 7, 7,    │         0 │ block7a_bn[0]… │   -   │
# │ (Activation)      │ 1152)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_project_… │ (None, 7, 7,    │   368,640 │ block7a_activ… │   Y   │
# │ (Conv2D)          │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7a_project_… │ (None, 7, 7,    │     1,280 │ block7a_proje… │   Y   │
# │ (BatchNormalizat… │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ top_conv (Conv2D) │ (None, 7, 7,    │   409,600 │ block7a_proje… │   Y   │
# │                   │ 1280)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ top_bn            │ (None, 7, 7,    │     5,120 │ top_conv[0][0] │   Y   │
# │ (BatchNormalizat… │ 1280)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ top_activation    │ (None, 7, 7,    │         0 │ top_bn[0][0]   │   -   │
# │ (Activation)      │ 1280)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ global_average_p… │ (None, 1280)    │         0 │ top_activatio… │   -   │
# │ (GlobalAveragePo… │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense (Dense)     │ (None, 128)     │   163,968 │ global_averag… │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_1 (Dense)   │ (None, 10)      │     1,290 │ dense[0][0]    │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 3,578,282 (13.65 MB)
#  Trainable params: 3,536,266 (13.49 MB)
#  Non-trainable params: 42,016 (164.12 KB)
